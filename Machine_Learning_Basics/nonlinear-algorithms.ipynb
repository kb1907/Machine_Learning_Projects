# %% [markdown]
# #### Hi all. 👍.
#
# #### I have recently published [Beginner Friendly Detailed Explained EDAs – For anyone at the beginnings of DS/ML journey](https://www.kaggle.com/general/253911#1393015) series.
#
# #### After getting positive feedback and requests for Beginner-Intermediate Friendly Machine Learning series, I started to publish the Machine Learning Basic Series, which would help anyone who wants to learn or refresh the basics of ML.
#
# #### What we have covered:
#
# #### [BIAS & VARIANCE TRADEOFF](https://www.kaggle.com/kaanboke/ml-basics-bias-variance-tradeoff) ✔️
#
# #### [LINEAR ALGORITHMS](https://www.kaggle.com/kaanboke/ml-basics-linear-algorithms)  ✔️
#
# #### In this post, I want to share with you :
#
# #### One of the essential concepts of Machine Learning Journey: **NONLINEAR ALGORITHMS**
#
# #### In this series, I will focus on the basic concepts with detailed explanations.
#
# #### After finishing the beginner-friendly explanation series, I will publish ML algorithms in action.
#
#
# #### **By the way, when you like the topic, you can show it by supporting** 👍
#
# ####  **Feel free to leave a comment in the notebook**.
#
#
# #### All the best 🤘

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*FUZS9K4JPqzfXDcC83BQTw.png)

# %% [markdown]
# Image Credit: https://miro.medium.com/

# %% [markdown]
# <a id="toc"></a>
#
# <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home">Table of Contents</h3>
#
# * [Algorithm](#0)
# * [Decision Tree](#1)
# * [Random Forests](#2)
# * [Gradient Boosting Trees](#3)
# * [XGBoost (Extreme Gradient Boosting)](#4)
# * [Naive Bayes](#5)
# * [KNN(k- Nearest Neighbors)](#6)
# * [Support Vector Machines (SVM)](#7)
# * [Further Reading](#8)
# * [References](#9)

# %% [markdown]
# <a id="0"></a>
# <font color="lightseagreen" size=+2.5><b>Algorithm</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>
#
#
# #### An algorithm is a set of instructions designed to perform a specific task. This can be a simple process, such as multiplying two numbers, or a complex operation, such as playing a compressed video file.
#
# Reference: https://techterms.com/definition/algorithm

# %% [markdown]
# #### As we have mentioned in our first notebook   [BIAS & VARIANCE TRADEOFF](https://www.kaggle.com/kaanboke/ml-basics-bias-variance-tradeoff), basically, in the Supervised Learning, we aim to build a model on the training data, which can make a prediction on the target variable.
#
#
# #### Since we constantly learn from the training data and make a prediction on the target variable, we need repetable procedures to perform this task.
#
# #### Accomplishing the task of learning data and make the best prediction on the test /unseen data is not an easy task. Machine learning algorithms try to succeed this task with the best prediction.
#
# #### Most of our times goes to improve our predictions and try to improve the performance of our models.
#
# #### Since we don't know which algorithm or model works best, we have to try different algorithms on the task.
#
# #### Before moving on to the details of the algorithms, we have to remember that
#
# #### Main aim of the any algorithm is to achieve **low bias** and **low variance**.

# %% [markdown]
# ![](https://i.pinimg.com/originals/90/00/c0/9000c0e50e1a97d0d12e85dc93affa5f.png)

# %% [markdown]
# Image Credit: www.pinterest.com

# %% [markdown]
# <a id="1"></a>
# <font color="lightseagreen" size=+2.5><b>Decision Tree</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# #### Decision trees are widely used models for classification and regression tasks. Essentially, they learn a hierarchy of if/else questions, leading to a decision.
# #### Decision trees are flexible and powerful algorithms for both regression and classification problems.
# #### To build a tree, the algorithm searches over all possible tests and finds the one that is most informative about the target variable.
# #### Building a tree continues until all leaves are pure leads to models that are very complex and highly overfit to the training data.
# #### Overfitting can be prevented by stopping the building tree at the early stage or building the tree but removing the nodes which do not contain much inofrmation

# %% [markdown]
# <img src="https://s3.ap-south-1.amazonaws.com/techleer/252.jpg" widht="599">

# %% [markdown]
# Image Credit: https://www.techleer.com/

# %% [markdown]
# <font color="blue" size=+0.5><b>Advantages</b></font>
#
#
# #### Decision trees are easy to understand even by the nonexperts.
# #### Decision trees do not require to scaling, standartization or normalization of the features
#
#
# <font color="blue" size=+0.5><b>Disadvantages</b></font>
#
#
# #### Decision trees are prone to overfitting and high variance
# #### Because of that, decision trees provide poor generalization

# %% [markdown]
# <a id="2"></a>
# <font color="lightseagreen" size=+2.5><b>Random Forests</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# #### As we have mentioned, one of the main disadvantages of decision trees is that they have high variance, tend to overfit and as an expected result we will have poor accuracy and poor generalization performance.
#
# #### To reduce high varaiance of the decision trees,ensemble methods (Bootstrap Aggregation, etc.) are used.
#
# #### **Ensemble**: Building a strong model by using a ensemble of weaker models.
#
# #### In the Random forest algorithm,  to reduce the variance, the sub-trees are learned so that the resulting predictions from all of the subtrees have less correlation.
#
# #### Basically, Random forest algorithm build many trees,even though each of them overfit the data, takes average of the their results to reduce overfitting.

# %% [markdown]
# <img src="https://www.pcigeomatics.com/geomatica-help/COMMON/references/images/RT_schematic.png">

# %% [markdown]
# Image Credit : https://www.pcigeomatics.com/

# %% [markdown]
# <font color="blue" size=+0.5><b>Advantages</b></font>
#
# #### Random Forests reduces the overfitting and high variance.
# #### The model works with both regression and the classification problems.
# #### The Random Forests model does not require normalizing of data.
#
#
# <font color="blue" size=+0.5><b>Disadvantages</b></font>
# #### The model requires more time to train and needs more computational power.
# #### The model is not easy to interpret
# #### The model does not provide high level performance on the high dimensional data (such as text data, etc.)

# %% [markdown]
# <a id="3"></a>
# <font color="lightseagreen" size=+2.5><b>Gradient Boosting Trees</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# #### As we have mentioned, one of the main disadvantages of decision trees is that they have high variance, tend to overfit and as an expected result we will havepoor accuracy and poor generalization performance.
#
# #### To reduce high varaiance of the decision trees,ensemble methods (Bootstrap Aggregation, etc.) are used.
#
# #### Gradient Boosting Trees are another ensemble method that combines multiple decision trees to create a more powerful model.
#
# #### Let's ask the obvious question: what is the difference between **<u>Gradient Boosting Trees and Random Forests</u>** ?
#
# ####  Gradient Boosting Trees model does not require randomization, instead uses pre-puning (reduces the size of decision trees by removing parts of the tree that do not provide power to classify instances).

# %%
from IPython import display
from base64 import b64decode
base64_data ='...'
display.Image(b64decode(base64_data))

# %% [markdown]
# Image Credit: relguzman.blogspot.com

# %% [markdown]
# <font color="blue" size=+0.5><b>Advantages</b></font>
#
# #### Gradient Boosting Trees reduces the overfitting and high variance.
# #### The model works with both regression and the classification problems.
#
#
#
# <font color="blue" size=+0.5><b>Disadvantages</b></font>
# #### Gradient Boosting Trees model are more sensitive to parameter settings than random forests.
# #### The model requires more time to train and needs more computational power.
# #### The model is not easy to interpret
# #### The model does not provide high level performance on the high dimensional data (such as text data, etc.)

# %% [markdown]
# <a id="4"></a>
# <font color="lightseagreen" size=+2.5><b>XGBoost (Extreme Gradient Boosting)</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# #### XGboost is the most widely used algorithm in machine learning, whether the problem is a classification or a regression problem. It is known for its good performance as compared to other algorithms.
#
# #### It provides a parallel tree boosting to solve many data science problems in a fast and accurate way.
#
# #### XGBoost's other features can be seen in the following image.

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*1kjLMDQMufaQoS-nNJfg1Q.png)

# %% [markdown]
# Image Credits: https://www.chaussurevip.fr/

# %% [markdown]
# <font color="blue" size=+0.5><b>Advantages</b></font>
#
# #### XGBoost is highly flexible ML algorithm and uses the power of parallel processing. It is faster than Gradient Boosting.
# #### XGBoost supports regularization.
# #### XGBoost is designed to handle missing data with its in-build features.
# #### XGBoost permits the user to run a cross-validation after each iteration.
#
#
# <font color="blue" size=+0.5><b>Disadvantages</b></font>
# #### The model requires more time to train.
# #### The model is not easy to interpret.

# %% [markdown]
# - **It would be good to see overview of the Decison Trees, Random Forest, Gradient Boosting and XGBoost**.

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*QJZ6W-Pck_W7RlIDwUIN9Q.jpeg)

# %% [markdown]
# Image Credit: miro.medium.com

# %% [markdown]
# <a id="5"></a>
# <font color="lightseagreen" size=+2.5><b>Naive Bayes</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# #### **Naive** : It is called Naive because it assumes that occurance of the each input is independent of the occurrence of other inputs.
#
# #### **Bayes** : It comes from Bayes's Theorem (<u>**see below formula**</u>)
#
# #### Naive Bayes algorithm is a classification algoritmh for both binary and multiclass classification problems.
#
# #### Naive Bayes algorithm is generally used in text analysis.
#
# #### Naive Bayes learns parameters by looking each input seperately and collects the simple statistics from each feature. Which basically means, model uses prior knowledge about the problem.
#
# #### Naive Bayes is very fast to learn from the training data.
#
# #### Naive Bayes is used for **Text Data Classification** (such as sentiment analysis, etc.), **Credit Scoring**,**Spam Filtering**, **Medical Data Classification** and **Real-Time Prediction**.
#
# #### Three kinds of naive Bayes classifiers:
#
# #### GaussianNB, BernoulliNB, and MultinomialNB
#
# #### **GaussianNB** can be used with any data.
#
# #### **BernoulliNB**, and **MultinomialNB** are mostly used with text data classification.

# %% [markdown]
# <font color="blue" size=+0.5><b>Bayes's Theorem </b></font>
#
# #### **P(A|B)** : Posterior probability.
# #### **P(A)** :  Prior probability
# #### **P(B|A)** : Probability of data d given that the hypothesis A was true.
# #### **P(B)** :  Probability of the data
#
#
# #### We try to get posterior probability by using prior probability.

# %% [markdown]
# <img src="https://www.kdnuggets.com/wp-content/uploads/bayes-nagesh-1.jpg" widht="599">

# %% [markdown]
# Image Credit: www.kdnuggets.com/

# %% [markdown]
# ![](https://media.cheatography.com/uploads/spriiprad_1589400525_Picturedd1.png)

# %% [markdown]
# Image Credit: https://media.cheatography.com/

# %% [markdown]
# <img src="https://storage.ning.com/topology/rest/1.0/file/get/2808297434?profile=original">

# %% [markdown]
# Image Credit: www.datasciencecentral.com/

# %% [markdown]
# <font color="blue" size=+0.5><b>Advantages</b></font>
#
# #### Naive Bayes models are fast to train and to predict
# #### Naive Bayes models' training procedures are easy to understand.
# #### The model works very well with high-dimensional sparse data and it is relatively robust to the parameters.
# #### Naive Bayes models are great baseline models and are often used on very large datasets, where training even a linear model might take too long.
#
#
# <font color="blue" size=+0.5><b>Disadvantages</b></font>
# #### Naive Bayes models assumes that all input variables are unrelated for that reason model can't learn from the relations between the input variables.
# #### <u> **Zero Frequency** </u>: Let's imagine, we have a categorical variable with three categories. (category A, category B, category C). In the training data we have only two categories of this categorical variable (category A, category B) and one of the category (category C) of the categorical variable wasn't present in the training data. The Naive Bayes model will assign it zero probability. But in the test data we have that category of the categorical variable. Since Naive Bayes model assign zero probability to category C, model won’t be able to make any predictions in this regard.

# %% [markdown]
# <a id="6"></a>
# <font color="lightseagreen" size=+2.5><b>KNN (k- Nearest Neighbors)</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# #### The KNN algorithm is one of the most simple and still very effective algorithm.
#
# #### When we have new data point, our model makes predictions by searching through the entire training set for the similar instances (K neighbors).
#
# ####

# %% [markdown]
# ![](https://miro.medium.com/max/591/1*kCqervQNQ5fGDfkFwrMzRQ.png)

# %% [markdown]
# Image Credit: miro.medium.com

# %% [markdown]
# <font color="blue" size=+0.5><b>Advantages</b></font>
# #### KNN model is simple. Only requires to adjust the number of neighbors, k and  which the distance metric to be used, then ready to go.
# #### KNN models are fast to train.
# #### KNN models are easy to understand.
# #### KNN models don't make any assumption about the data. For example, linear regression expects linear relation between input and target variables, but KNN models do not require any assumption about the data and work with it.
#
#
# <font color="blue" size=+0.5><b>Disadvantages</b></font>
# #### KNN models needs preprocessing the data (scaling and balancing).
# #### KNN models are sensitive to the outliers
# #### KNN models can't deal with the missing values.
# #### Requires large memory to store the training data.
# #### Since it requires a lot of memory and its' inability to deal with many features, KNN models are not often used in the practice.

# %% [markdown]
# <a id="7"></a>
# <font color="lightseagreen" size=+2.5><b>Support Vector Machines (SVM)</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# #### Even though SVW is used for both regression and classification problems, it is primarily used for classification problems.
#
# #### The main goal of the SVM algorithm is to create the best line or decision boundary. This best decision boundary is called a **hyperplane**.
#
# #### Support vectors in this sense, are the data points that are closer to a hyperplane.
#
# #### SVM aims to maximize the distance (margin) between each of the support vectors.
#
# #### SVM works well with the high dimensional data (Text data, gene data, image data, etc.)

# %% [markdown]
# ![](https://static.javatpoint.com/tutorial/machine-learning/images/support-vector-machine-algorithm.png)

# %% [markdown]
# Image Credit : www.javatpoint.com

# %% [markdown]
# <font color="blue" size=+0.5><b>Advantages</b></font>
#
# #### SVM draws boundary between the data points are not linearly separable.
# #### SVM  works effectively in the higher dimension.
# #### SVM is not affected by the outliers, model's only concern is support vectors.
#
#
#
# <font color="blue" size=+0.5><b>Disadvantages</b></font>
# #### SVM is slow when dealing with the larger dataset.
# #### Even though SVM works well with the seperable classes, if classes are overlapped, SVM shows poor performance.

# %% [markdown]
# **Before finishing, let's see the advantages and disadvantages of the some of the algorithms we have mentioned till now.**

# %% [markdown]
# [](https://www.kdnuggets.com/wp-content/uploads/bayes-nagesh-1.jpg)

# %% [markdown]
# ![](https://miro.medium.com/max/875/1*05DngXXh_tH1RHF5UaXWjA.jpeg)

# %% [markdown]
# Image Credit : www.dataiku.com

# %% [markdown]
# #### In this study, we focus on the **NONLINEAR ALGORITHMS**.
#
# #### After finishing the beginner-friendly explanation series, I will publish ML algorithms in action.
#
#
# #### By the way, when you like the topic, you can show it by supporting 👍
#
#  #### All the best 🤘

# %% [markdown]
# <a id="8"></a>
# <font color="darkblue" size=+1.5><b>Further Reading</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>
#
#
# [Machine Learning - Beginner &Intermediate-Friendly BOOKS](https://www.kaggle.com/general/255972)

# %% [markdown]
# <a id="9"></a>
# <font color="darkblue" size=+1.5><b>References:</b></font>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Table of Contents</a>
#
#
# - [Introduction to Machine Learning with Python](https://www.amazon.com/Introduction-Machine-Learning-Python-Scientists/dp/1449369413)
#
# - [Master Machine Learning Algorithms](https://machinelearningmastery.com/master-machine-learning-algorithms/)
